# %%
import os
import nltk
from nltk.corpus import brown

# %%
# !python -m nltk.downloader all
# Out:
# /usr/local/anaconda/lib/python3.7/runpy.py:125: RuntimeWarning: 'nltk.downloader' found in sys.modules after import of package 'nltk', but prior to execution of 'nltk.downloader'; this may result in unpredictable behaviour
#   warn(RuntimeWarning(msg))
# [nltk_data] Downloading collection 'all'
# [nltk_data]    |
# [nltk_data]    | Downloading package abc to /home/ubuntu/nltk_data...
# [nltk_data]    |   Unzipping corpora/abc.zip.
# [nltk_data]    | Downloading package alpino to
# [nltk_data]    |     /home/ubuntu/nltk_data...
# [nltk_data]    |   Unzipping corpora/alpino.zip.
# [nltk_data]    | Downloading package biocreative_ppi to
# [nltk_data]    |     /home/ubuntu/nltk_data...
# [nltk_data]    |   Unzipping corpora/biocreative_ppi.zip.
# [nltk_data]    | Downloading package brown to
# [nltk_data]    |     /home/ubuntu/nltk_data...
# [nltk_data]    |   Unzipping corpora/brown.zip.
# [nltk_data]    | Downloading package brown_tei to
# ...

# %%
print(os.listdir(nltk.data.find("corpora")))
# Out:
# ['europarl_raw.zip', 'paradigms.zip', 'smultron.zip', 'product_reviews_2.zip', 'unicode_samples', 'comparative_sentences.zip', 'wordnet_ic', 'udhr2.zip', 'inaugural', 'chat80', 'omw', 'omw.zip', 'dependency_treebank.zip', 'universal_treebanks_v20.zip', 'product_reviews_1.zip', 'sinica_treebank.zip', 'lin_thesaurus', 'nps_chat', 'swadesh.zip', 'knbc.zip', 'rte', 'indian', 'jeita.zip', 'genesis', 'treebank.zip', 'unicode_samples.zip', 'nps_chat.zip', 'ptb', 'movie_reviews', 'senseval.zip', 'switchboard.zip', 'floresta.zip', 'cess_esp.zip', 'kimmo', 'pil.zip', 'rte.zip', 'crubadan.zip', 'opinion_lexicon', 'qc.zip', 'verbnet.zip', 'senseval', 'mte_teip5.zip', 'sentiwordnet.zip', 'gutenberg', 'conll2000.zip', 'floresta', 'sentence_polarity.zip', 'biocreative_ppi.zip', 'subjectivity.zip', 'framenet_v17.zip', 'shakespeare', 'cess_cat', 'abc', 'panlex_swadesh.zip', 'state_union', 'movie_reviews.zip', 'dolch.zip', 'biocreative_ppi', 'abc.zip', 'dolch', 'cmudict', 'subjectivity', 'sinica_treeb
# ...

# %%
nltk.corpus.gutenberg.fileids()
# Out:
# ['austen-emma.txt',
#  'austen-persuasion.txt',
#  'austen-sense.txt',
#  'bible-kjv.txt',
#  'blake-poems.txt',
#  'bryant-stories.txt',
#  'burgess-busterbrown.txt',
#  'carroll-alice.txt',
#  'chesterton-ball.txt',
#  'chesterton-brown.txt',
#  'chesterton-thursday.txt',
#  'edgeworth-parents.txt',
#  'melville-moby_dick.txt',
#  'milton-paradise.txt',
#  'shakespeare-caesar.txt',
#  'shakespeare-hamlet.txt',
#  'shakespeare-macbeth.txt',
#  'whitman-leaves.txt']

# %%
hamlet_words  = nltk.corpus.gutenberg.words('shakespeare-hamlet.txt')
hamlet_para  = nltk.corpus.gutenberg.raw('shakespeare-hamlet.txt')

# %%
for word in hamlet_words:
    print(word,sep=" ",end=" ")
# Out:
# [ The Tragedie of Hamlet by William Shakespeare 1599 ] Actus Primus . Scoena Prima . Enter Barnardo and Francisco two Centinels . Barnardo . Who ' s there ? Fran . Nay answer me : Stand & vnfold your selfe Bar . Long liue the King Fran . Barnardo ? Bar . He Fran . You come most carefully vpon your houre Bar . ' Tis now strook twelue , get thee to bed Francisco Fran . For this releefe much thankes : ' Tis bitter cold , And I am sicke at heart Barn . Haue you had quiet Guard ? Fran . Not a Mouse stirring Barn . Well , goodnight . If you do meet Horatio and Marcellus , the Riuals of my Watch , bid them make hast . Enter Horatio and Marcellus . Fran . I thinke I heare them . Stand : who ' s there ? Hor . Friends to this ground Mar . And Leige - men to the Dane Fran . Giue you good night Mar . O farwel honest Soldier , who hath relieu ' d you ? Fra . Barnardo ha ' s my place : giue you goodnight . Exit Fran . Mar . Holla Barnardo Bar . Say , what is Horatio there ? Hor . A peece of him Ba
# ...

# %% [markdown]
# # Tokenization

# %%
from nltk.tokenize import word_tokenize

# %%
hamlet_tokens = word_tokenize(hamlet_para)

# %%
print(len(hamlet_words))
print(len(hamlet_tokens))
# Out:
# 37360
# 36382

# %%
from nltk.probability import FreqDist

# %%
fdist = FreqDist()

# %%
for word in hamlet_tokens:
    fdist[word.lower()]+=1
fdist
# Out:
# FreqDist({',': 2892, '.': 1879, 'the': 993, 'and': 862, 'to': 683, 'of': 610, ':': 566, 'i': 560, 'you': 527, 'my': 502, ...})

# %%
from nltk.tokenize import blankline_tokenize

# %%
hamlet_blank=blankline_tokenize(hamlet_para)

# %%
hamlet_blank
# Out:
# ['[The Tragedie of Hamlet by William Shakespeare 1599]',
#  'Actus Primus. Scoena Prima.',
#  'Enter Barnardo and Francisco two Centinels.',
#  "Barnardo. Who's there?\n  Fran. Nay answer me: Stand & vnfold\nyour selfe",
#  'Bar. Long liue the King',
#  'Fran. Barnardo?\n  Bar. He',
#  'Fran. You come most carefully vpon your houre',
#  "Bar. 'Tis now strook twelue, get thee to bed Francisco",
#  "Fran. For this releefe much thankes: 'Tis bitter cold,\nAnd I am sicke at heart",
#  'Barn. Haue you had quiet Guard?\n  Fran. Not a Mouse stirring',
#  'Barn. Well, goodnight. If you do meet Horatio and\nMarcellus, the Riuals of my Watch, bid them make hast.\nEnter Horatio and Marcellus.',
#  "Fran. I thinke I heare them. Stand: who's there?\n  Hor. Friends to this ground",
#  'Mar. And Leige-men to the Dane',
#  'Fran. Giue you good night',
#  "Mar. O farwel honest Soldier, who hath relieu'd you?\n  Fra. Barnardo ha's my place: giue you goodnight.",
#  'Exit Fran.',
# ...

# %%
from nltk.util import bigrams,trigrams,ngrams

# %%
string = "Long liue the King Fran . Barnardo ? Bar . He Fran . You come most carefully vpon your houre Bar . ' Tis now strook twelue , get thee to bed Francisco Fran . For this releefe much thankes : ' Tis bitter cold , And I am sicke at heart Barn . Haue you had quiet Guard ? Fran"
quote_tokens = nltk.word_tokenize(string)
quote_tokens
# Out:
# ['Long',
#  'liue',
#  'the',
#  'King',
#  'Fran',
#  '.',
#  'Barnardo',
#  '?',
#  'Bar',
#  '.',
#  'He',
#  'Fran',
#  '.',
#  'You',
#  'come',
#  'most',
#  'carefully',
#  'vpon',
#  'your',
#  'houre',
#  'Bar',
#  '.',
#  "'",
#  'Tis',
#  'now',
#  'strook',
#  'twelue',
#  ',',
#  'get',
#  'thee',
#  'to',
#  'bed',
#  'Francisco',
#  'Fran',
#  '.',
#  'For',
#  'this',
#  'releefe',
#  'much',
#  'thankes',
#  ':',
#  "'",
#  'Tis',
#  'bitter',
#  'cold',
#  ',',
#  'And',
#  'I',
#  'am',
#  'sicke',
#  'at',
#  'heart',
#  'Barn',
#  '.',
#  'Haue',
#  'you',
#  'had',
#  'quiet',
#  'Guard',
#  '?',
#  'Fran']

# %%
quotes_bigrams =  list(nltk.bigrams(quote_tokens))
quotes_bigrams
# Out:
# [('Long', 'liue'),
#  ('liue', 'the'),
#  ('the', 'King'),
#  ('King', 'Fran'),
#  ('Fran', '.'),
#  ('.', 'Barnardo'),
#  ('Barnardo', '?'),
#  ('?', 'Bar'),
#  ('Bar', '.'),
#  ('.', 'He'),
#  ('He', 'Fran'),
#  ('Fran', '.'),
#  ('.', 'You'),
#  ('You', 'come'),
#  ('come', 'most'),
#  ('most', 'carefully'),
#  ('carefully', 'vpon'),
#  ('vpon', 'your'),
#  ('your', 'houre'),
#  ('houre', 'Bar'),
#  ('Bar', '.'),
#  ('.', "'"),
#  ("'", 'Tis'),
#  ('Tis', 'now'),
#  ('now', 'strook'),
#  ('strook', 'twelue'),
#  ('twelue', ','),
#  (',', 'get'),
#  ('get', 'thee'),
#  ('thee', 'to'),
#  ('to', 'bed'),
#  ('bed', 'Francisco'),
#  ('Francisco', 'Fran'),
#  ('Fran', '.'),
#  ('.', 'For'),
#  ('For', 'this'),
#  ('this', 'releefe'),
#  ('releefe', 'much'),
#  ('much', 'thankes'),
#  ('thankes', ':'),
#  (':', "'"),
#  ("'", 'Tis'),
#  ('Tis', 'bitter'),
#  ('bitter', 'cold'),
#  ('cold', ','),
#  (',', 'And'),
#  ('And', 'I'),
#  ('I', 'am'),
#  ('am', 'sicke'),
#  ('sicke', 'at'),
# ...

# %%
quotes_trigrams =  list(nltk.trigrams(quote_tokens))
quotes_trigrams
# Out:
# [('Long', 'liue', 'the'),
#  ('liue', 'the', 'King'),
#  ('the', 'King', 'Fran'),
#  ('King', 'Fran', '.'),
#  ('Fran', '.', 'Barnardo'),
#  ('.', 'Barnardo', '?'),
#  ('Barnardo', '?', 'Bar'),
#  ('?', 'Bar', '.'),
#  ('Bar', '.', 'He'),
#  ('.', 'He', 'Fran'),
#  ('He', 'Fran', '.'),
#  ('Fran', '.', 'You'),
#  ('.', 'You', 'come'),
#  ('You', 'come', 'most'),
#  ('come', 'most', 'carefully'),
#  ('most', 'carefully', 'vpon'),
#  ('carefully', 'vpon', 'your'),
#  ('vpon', 'your', 'houre'),
#  ('your', 'houre', 'Bar'),
#  ('houre', 'Bar', '.'),
#  ('Bar', '.', "'"),
#  ('.', "'", 'Tis'),
#  ("'", 'Tis', 'now'),
#  ('Tis', 'now', 'strook'),
#  ('now', 'strook', 'twelue'),
#  ('strook', 'twelue', ','),
#  ('twelue', ',', 'get'),
#  (',', 'get', 'thee'),
#  ('get', 'thee', 'to'),
#  ('thee', 'to', 'bed'),
#  ('to', 'bed', 'Francisco'),
#  ('bed', 'Francisco', 'Fran'),
#  ('Francisco', 'Fran', '.'),
#  ('Fran', '.', 'For'),
#  ('.', 'For', 'this'),
#  ('For', 'this', 'releefe'),
# ...

# %%
quotes_ngrams =  list(nltk.ngrams(quote_tokens,4))
quotes_ngrams
# Out:
# [('Long', 'liue', 'the', 'King'),
#  ('liue', 'the', 'King', 'Fran'),
#  ('the', 'King', 'Fran', '.'),
#  ('King', 'Fran', '.', 'Barnardo'),
#  ('Fran', '.', 'Barnardo', '?'),
#  ('.', 'Barnardo', '?', 'Bar'),
#  ('Barnardo', '?', 'Bar', '.'),
#  ('?', 'Bar', '.', 'He'),
#  ('Bar', '.', 'He', 'Fran'),
#  ('.', 'He', 'Fran', '.'),
#  ('He', 'Fran', '.', 'You'),
#  ('Fran', '.', 'You', 'come'),
#  ('.', 'You', 'come', 'most'),
#  ('You', 'come', 'most', 'carefully'),
#  ('come', 'most', 'carefully', 'vpon'),
#  ('most', 'carefully', 'vpon', 'your'),
#  ('carefully', 'vpon', 'your', 'houre'),
#  ('vpon', 'your', 'houre', 'Bar'),
#  ('your', 'houre', 'Bar', '.'),
#  ('houre', 'Bar', '.', "'"),
#  ('Bar', '.', "'", 'Tis'),
#  ('.', "'", 'Tis', 'now'),
#  ("'", 'Tis', 'now', 'strook'),
#  ('Tis', 'now', 'strook', 'twelue'),
#  ('now', 'strook', 'twelue', ','),
#  ('strook', 'twelue', ',', 'get'),
#  ('twelue', ',', 'get', 'thee'),
#  (',', 'get', 'thee', 'to'),
# ...

# %% [markdown]
# # Stemming

# %%
from nltk.stem import PorterStemmer
from nltk.stem import LancasterStemmer
pst=PorterStemmer()
lst=LancasterStemmer()

# %%
print(pst.stem("having"))
print(lst.stem("having"))
# Out:
# have
# hav

# %%
words_to_stem = ["give","giving","given","gave"]
for words in words_to_stem:
    print(words+" (PorterStemmer):"+pst.stem(words))
    print(words+" (LancasterStemmer):"+lst.stem(words))
# Out:
# give (PorterStemmer):give
# give (LancasterStemmer):giv
# giving (PorterStemmer):give
# giving (LancasterStemmer):giv
# given (PorterStemmer):given
# given (LancasterStemmer):giv
# gave (PorterStemmer):gave
# gave (LancasterStemmer):gav

# %%
from nltk.stem import wordnet
from nltk.stem import WordNetLemmatizer
word_lem=WordNetLemmatizer()

# %%
word_lem.lemmatize('corpora')
# Out:
# 'corpus'

# %%
for words in words_to_stem:
    print(words+" WordNetLemmatizer :"+word_lem.lemmatize(words))
# Out:
# give WordNetLemmatizer :give
# giving WordNetLemmatizer :giving
# given WordNetLemmatizer :given
# gave WordNetLemmatizer :gave

# %%
import re
punctuations = re.compile(r'[-.?!,:;()|0-9]')

# %%
post_punctuations = []
for words in hamlet_tokens:
    word=punctuations.sub("",words)
    if len(word)>0:
        post_punctuations.append(word)

# %%
post_punctuations
# Out:
# ['[',
#  'The',
#  'Tragedie',
#  'of',
#  'Hamlet',
#  'by',
#  'William',
#  'Shakespeare',
#  ']',
#  'Actus',
#  'Primus',
#  'Scoena',
#  'Prima',
#  'Enter',
#  'Barnardo',
#  'and',
#  'Francisco',
#  'two',
#  'Centinels',
#  'Barnardo',
#  'Who',
#  "'s",
#  'there',
#  'Fran',
#  'Nay',
#  'answer',
#  'me',
#  'Stand',
#  '&',
#  'vnfold',
#  'your',
#  'selfe',
#  'Bar',
#  'Long',
#  'liue',
#  'the',
#  'King',
#  'Fran',
#  'Barnardo',
#  'Bar',
#  'He',
#  'Fran',
#  'You',
#  'come',
#  'most',
#  'carefully',
#  'vpon',
#  'your',
#  'houre',
#  'Bar',
#  "'T",
#  'is',
#  'now',
#  'strook',
#  'twelue',
#  'get',
#  'thee',
#  'to',
#  'bed',
#  'Francisco',
#  'Fran',
#  'For',
#  'this',
#  'releefe',
#  'much',
#  'thankes',
#  "'T",
#  'is',
#  'bitter',
#  'cold',
#  'And',
#  'I',
#  'am',
#  'sicke',
#  'at',
#  'heart',
#  'Barn',
#  'Haue',
#  'you',
#  'had',
#  'quiet',
#  'Guard',
#  'Fran',
#  'Not',
#  'a',
#  'Mouse',
#  'stirring',
#  'Barn',
# ...

# %%
for token in hamlet_tokens:
    tags=nltk.pos_tag([token])
    print(tags)
# Out:
# [('[', 'NN')]
# [('The', 'DT')]
# [('Tragedie', 'NN')]
# [('of', 'IN')]
# [('Hamlet', 'NN')]
# [('by', 'IN')]
# [('William', 'NNP')]
# [('Shakespeare', 'NN')]
# [('1599', 'CD')]
# [(']', 'NN')]
# [('Actus', 'NN')]
# [('Primus', 'NN')]
# [('.', '.')]
# [('Scoena', 'NN')]
# [('Prima', 'NN')]
# [('.', '.')]
# [('Enter', 'NN')]
# [('Barnardo', 'NN')]
# [('and', 'CC')]
# [('Francisco', 'NNP')]
# [('two', 'CD')]
# [('Centinels', 'NNS')]
# [('.', '.')]
# [('Barnardo', 'NN')]
# [('.', '.')]
# [('Who', 'WP')]
# [("'s", 'POS')]
# [('there', 'RB')]
# [('?', '.')]
# [('Fran', 'NN')]
# [('.', '.')]
# [('Nay', 'NN')]
# [('answer', 'NN')]
# [('me', 'PRP')]
# [(':', ':')]
# [('Stand', 'NN')]
# [('&', 'CC')]
# [('vnfold', 'NN')]
# [('your', 'PRP$')]
# [('selfe', 'NN')]
# [('Bar', 'NN')]
# [('.', '.')]
# [('Long', 'RB')]
# [('liue', 'NN')]
# [('the', 'DT')]
# [('King', 'VBG')]
# [('Fran', 'NN')]
# [('.', '.')]
# [('Barnardo', 'NN')]
# [('?', '.')]
# [('Bar', 'NN')]
# [('.', '.')]
# [('He', 'PRP')]
# ...

# %%
from nltk import ne_chunk

# %%
pos_tags_tokens = nltk.pos_tag(hamlet_tokens)
NE_NET =  ne_chunk(pos_tags_tokens)

# %%
NE_NET
# Out:
# ---------------------------------------------------------------------------
# TclError                                  Traceback (most recent call last)
# /usr/local/anaconda/lib/python3.7/site-packages/IPython/core/formatters.py in __call__(self, obj)
#     343             method = get_real_method(obj, self.print_method)
#     344             if method is not None:
# --> 345                 return method()
#     346             return None
#     347         else:
#
# /usr/local/anaconda/lib/python3.7/site-packages/nltk/tree.py in _repr_png_(self)
#     778         from nltk.internals import find_binary
#     779
# --> 780         _canvas_frame = CanvasFrame()
#     781         widget = tree_to_treesegment(_canvas_frame.canvas(), self)
#     782         _canvas_frame.add_widget(widget)
#
# /usr/local/anaconda/lib/python3.7/site-packages/nltk/draw/util.py in __init__(self, parent, **kw)
#    1793         # If no parent was given, set up a top-level window.
# ...

# %%
import pandas as pd
import numpy as np
from sklearn.feature_extraction.text import CountVectorizer

# %%
from nltk.corpus import movie_reviews

# %%
neg_rev = movie_reviews.fileids('neg')
rev = nltk.corpus.movie_reviews.words('pos/cv000_29590.txt')

# %%
rev_list = []

# %%
for rev in neg_rev:
    rev_text_neg = rev =  nltk.corpus.movie_reviews.words(rev)
    review_one_string = " ".join(rev_text_neg)
    review_one_string = review_one_string.replace(' ,',',')
    review_one_string = review_one_string.replace(' .','.')
    review_one_string = review_one_string.replace("\' ","'")
    review_one_string = review_one_string.replace(" \'","'")
    rev_list.append(review_one_string)

# %%
len(rev_list)
# Out:
# 1000

# %%
pos_rev = movie_reviews.fileids('pos')
for rev_pos in pos_rev:
    rev_text_pos =  nltk.corpus.movie_reviews.words(rev_pos)
    review_one_string = " ".join(rev_text_pos)
    review_one_string = review_one_string.replace(' ,',',')
    review_one_string = review_one_string.replace(' .','.')
    review_one_string = review_one_string.replace("\' ","'")
    review_one_string = review_one_string.replace(" \'","'")
    rev_list.append(review_one_string)

# %%
len(rev_list)
# Out:
# 2000

# %%
neg_target =  np.zeros((1000,),dtype=np.int)
pos_target =  np.ones((1000,),dtype=np.int)

# %%
target_list = []
for neg_tar in neg_target:
    target_list.append(neg_tar)
for pos_tar in pos_target:
    target_list.append(pos_tar)

# %%
y=pd.Series(target_list)

# %%
count_vect = CountVectorizer(lowercase=True,stop_words='english',min_df=2)

# %%
X_count_vect = count_vect.fit_transform(rev_list)

# %%
X_names =  count_vect.get_feature_names()

# %%
X_count_vect = pd.DataFrame(X_count_vect.toarray(),columns =X_names)

# %%
from sklearn.model_selection import train_test_split
from sklearn import metrics
from sklearn.metrics import confusion_matrix

# %%
X_train_cv,X_test_cv,y_train_cv,y_test_cv = train_test_split(X_count_vect,y,test_size=0.25,random_state=5)

# %%
from sklearn.naive_bayes import GaussianNB
from sklearn.naive_bayes import MultinomialNB

# %%
clf_cv = MultinomialNB()
clf_cv.fit(X_train_cv,y_train_cv)
# Out:
# MultinomialNB(alpha=1.0, class_prior=None, fit_prior=True)

# %%
y_pred_cv = clf_cv.predict(X_test_cv)
type(y_pred_cv)
# Out:
# numpy.ndarray

# %%
print(metrics.accuracy_score(y_test_cv,y_pred_cv))
# Out:
# 0.798

# %%
score_clf_cv = confusion_matrix(y_test_cv,y_pred_cv)
score_clf_cv
# Out:
# array([[213,  45],
#        [ 56, 186]])
